# %% [markdown]
# # Notebook to clean up and parse eldenring wiki data

# %%
# %matplotlib inline

# %%
from bs4 import BeautifulSoup
import re
from fastcore.foundation import L
from matplotlib import pyplot as plt
from fastcore.basics import groupby, itemgetter

# Load the HTML content from a file
html_file_path = '/Users/cck/Desktop/elden_ring_dialogue.html'
with open(html_file_path, 'r', encoding='utf-8') as file:
    html_content = file.read()

# Parse the HTML
soup = BeautifulSoup(html_content, 'html.parser')

# %%
# Find the "TalkMsg.fmg" section
talk_msg_section = soup.find('h2', string='TalkMsg.fmg')

# %%
# Initialize a list to hold the extracted paragraphs
extracted_paragraphs = L()

# Regular expression pattern to find and remove brackets and their contents
pattern = r'\[\d+\]\s*'

def clean_text(text):
    # Use re.sub() to replace the pattern with an empty string
    cleaned_text = re.sub(pattern, '', text)
    cleaned_text = cleaned_text.strip()
    return cleaned_text


def text_is_empty(text):
    return text in ('', ' ', '\n')


def is_name_just_digits(speaker_name):
    return re.fullmatch(r'\d+', speaker_name) is not None


entries = L()

# Start extracting from the found header
current_tag = talk_msg_section.next_sibling
current_speaker = None
current_turn = None

while current_tag:
    if current_tag.name == 'h3':
        current_speaker = current_tag.text
        current_speaker = clean_text(current_speaker)
    elif current_tag.name == 'h4':
        current_turn = current_tag.text
    elif current_tag.name == 'p':
        # Remove brackets and their contents
        text = current_tag.get_text(" ", strip=True)
        text = clean_text(text)
        if not text_is_empty(text):
            entry = {
                'words': text,
                'speaker': current_speaker,
                'turn': current_turn,
            }
            entries.append(entry)
    
    current_tag = current_tag.next_sibling if current_tag.next_sibling else None

# the first entry is garbage
entries = entries[1:]

# clean up digit-only names
entries = entries.filter(lambda x: (x['speaker'] and not is_name_just_digits(x['speaker'])))

# %%
len(entries)
# Out:
# 2270

# %%
entries[5]
# Out:
# {'words': 'Phew. It is done.', 'speaker': 'Melina', 'turn': 'Section 22'}

# %%
# group the speakers together
by_speaker = groupby(entries, itemgetter('speaker'))

# %%
# counts up words by speaker
def count_words(entries):
    return sum(len(entry['words'].split()) for entry in entries)

# %%
# find how much each speaker says
speaker_counts = {speaker: count_words(entries) for speaker, entries in by_speaker.items()}

# sort the speakers by how much they talk
speaker_counts_sorted = dict(sorted(speaker_counts.items(), key=itemgetter(1), reverse=True))

# %%
by_speaker['Baleful Shadow']
# Out:
# [{'words': "Oh, it's you... It's me, Blaidd. Old Iji trapped me here. Told me I'd bring nought but bale to Lady Ranni. But there's no chance that could happen. I'm part of her being. Her very shadow... I thought old Iji knew as much... Honestly, I don't know what's going on anymore...",
#   'speaker': 'Baleful Shadow',
#   'turn': 'Section 00'},
#  {'words': "I don't understand. Why would Iji do this... I could never intend harm to Lady Ranni. What's he thinking...",
#   'speaker': 'Baleful Shadow',
#   'turn': 'Section 01'},
#  {'words': "My thanks, friend. I'm going to see mistress Ranni, now. I don't know what came over old Iji, but even if the odds are slim, I need to check the mistress is safe. Now, Ranni can finally set in motion the fight against her fate she's dreamt of for so long.",
#   'speaker': 'Baleful Shadow',
#   'turn': 'Section 10'},
#  {'words': "I'm going to see mistress Ranni, now. I don't know what came over old Iji, but even if the odds are slim, I need to check the mistress is safe.",
#   'speaker': 'Baleful Shadow',
#   'turn': 'Section 11'},
#  {'words': "... No. I'm part of her very being! I could never betray her! No matter what might happen... Ranni... She needs me...",
#   'speaker': 'Baleful Shadow',
#   'turn': 'Section 20'}]

# %%
speaker_counts_sorted
# Out:
# {'Sir Gideon Ofnir, the All-Knowing': 2553,
#  'Alexander, Warrior Jar': 2270,
#  'Sorcerer Rogier': 1663,
#  'Preceptor Seluvis': 1656,
#  'Rya the Scout': 1588,
#  'White Mask Varré': 1556,
#  'Roderika, Spirit Tuner': 1479,
#  'Scribe Corhyn': 1445,
#  'Jar-Bairn': 1403,
#  'Merchant Kalé': 1372,
#  'War Counselor Iji': 1350,
#  'Sage Gowry': 1303,
#  'Shabriri': 1290,
#  'Tanith, Volcano Manor Proprietress': 1272,
#  'Patches': 1245,
#  'Demi-Human Boc': 1242,
#  'Irina of Morne': 1182,
#  'D, Hunter of the Dead': 1176,
#  'Fia, Deathbed Companion': 1173,
#  'Sorceress Sellen': 1166,
#  'Blaidd the Half-Wolf': 1145,
#  'Renna the Witch': 1129,
#  'Kenneth Haight, Limgrave Heir': 1036,
#  'Millicent': 1023,
#  'Potentate Diallos': 957,
#  'Miriel, Pastor of Vows': 946,
#  'Finger Reader Enia': 920,
#  'Reeling Rico': 911,
#  'Recusant Bernahl': 871,
#  'Nepheli Loux, Warrior': 868,
#  'Witch-Hunter Jerren': 779,
#  'Sorcerer Thops': 728,
#  'Latenna the Albinauric': 675,
#  'Remembrance Duplication Menu': 621,
#  'Blackguard': 607,
#  'Gatekeeper Gostoc': 574,
#  'Smithing Master Hewg': 566,
#  'Dung Eater': 562,
#  'Asimi, Silver Tear': 554,
#  'Melina': 493,
#  'Ranni the Witch': 361,
#  'Edgar the Revenger': 276,
#  'Rennala, Queen of the Full Moon': 258,
#  'Gurranq, Beast Clergyman': 232,
#  'Old Albus': 193,
#  'Baleful Shadow': 173,
#  'Hermit Merchant': 110,
#  'Boc the Seamster': 99,
#  'Ashes of War Menu': 80,
#  'Multiplayer Menu': 66,
#  'Sites of Grace': 64,
#  'Roundtable Hold': 64,
#  'Map Menu': 64,
#  'Message Menu': 60,
#  'Zweihander': 60,
#  'Memorize Spells Menu': 58,
#  'Wakizashi': 58,
#  'Serpent-Hunter': 57,
#  'Rapier': 55,
#  'Crystal Sword': 54,
#  'Cranial Vessel Candlestand': 54,
#  'Crystal Spear': 54,
#  'Vulgar Militia Saw': 54,
#  "Hoslow's Petal Whip": 54,
#  'Axe of Godfrey': 54,
#  'Ghostflame Torch': 54,
#  'The Map': 53,
#  'Coded Sword': 53,
#  'Sacred Relic Sword': 53,
#  "Magma Wyrm's Scalesword": 52,
#  'Allocating Flask Uses': 51,
#  'Dismounter': 51,
#  'Omen Cleaver': 50,
#  'Rivers of Blood': 50,
#  'Giant-Crusher': 50,
#  "Miquellan Knight's Sword": 49,
#  'Cane Sword': 49,
#  'Bastard Sword': 49,
#  "Marais Executioner's Sword": 49,
#  'Grafted Blade Greatsword': 49,
#  'Stone Club': 49,
#  "Devourer's Scepter": 49,
#  'Dense Fog of Sleep': 48,
#  'Sorting the Chest': 48,
#  'Reduvia': 48,
#  'Pulley Crossbow': 48,
#  'Sword of St. Trina': 47,
#  'Greatsword': 47,
#  "Maliketh's Black Blade": 47,
#  'Starscourge Greatsword': 47,
#  "Troll Knight's Sword": 47,
#  'Scepter of the All-Knowing': 47,
#  'Greataxe': 47,
#  'Vulgar Militia Shotel': 47,
#  'Pillory Shield': 47,
#  'Spiralhorn Shield': 47,
#  'Gravel Stone Seal': 47,
#  "Carian Knight's Sword": 46,
#  'Golden Order Greatsword': 46,
#  'Claymore': 46,
#  'Royal Greatsword': 46,
#  'Great Stars': 46,
#  'Bolt of Gransax': 46,
#  "Mohgwyn's Sacred Spear": 46,
#  "Pest's Glaive": 46,
#  'Scythe': 46,
#  "Veteran's Prosthesis": 46,
#  'Cipher Pata': 46,
#  "Sentry's Torch": 46,
#  'Rebirth Menu': 45,
#  "Banished Knight's Greatsword": 45,
#  "Helphen's Steeple": 45,
#  'Antspur Rapier': 45,
#  'Ringed Finger': 45,
#  'Axe of Godrick': 45,
#  'Winged Greathorn': 45,
#  "Inquisitor's Girandole": 45,
#  "Banished Knight's Halberd": 45,
#  'Great Club': 45,
#  'Fingerprint Stone Shield': 45,
#  'Visage Shield': 45,
#  'Full Moon Crossbow': 45,
#  'Smithing Menu': 44,
#  'Weathered Straight Sword': 44,
#  'Sword of Milos': 44,
#  "Bandit's Curved Sword": 44,
#  'Cross-Naginata': 44,
#  'Grave Scythe': 44,
#  "Beastman's Jar-Shield": 44,
#  'Marred Leather Shield': 44,
#  'Marred Wooden Shield': 44,
#  'Flame Crest Wooden Shield': 44,
#  'Pulley Bow': 44,
#  'Blade of Calling': 43,
#  "Troll's Golden Sword": 43,
#  "Rogier's Rapier": 43,
#  'Godskin Peeler': 43,
#  'Brick Hammer': 43,
#  'Halberd': 43,
#  'Icon Shield': 43,
#  "Prince of Death's Staff": 43,
#  'Dragon Communion Seal': 43,
#  'Equipment Menu': 42,
#  "Lordsworn's Straight Sword": 42,
#  "Lordsworn's Greatsword": 42,
#  "Knight's Greatsword": 42,
#  'Ruins Greatsword': 42,
#  "Beastman's Cleaver": 42,
#  "Varré's Bouquet": 42,
#  "Marika's Hammer": 42,
#  'Flail': 42,
#  'Stormhawk Axe': 42,
#  "Commander's Standard": 42,
#  'Grafted Dragon': 42,
#  'Erdtree Greatshield': 42,
#  'Staff of the Guilty': 42,
#  'Erdtree Greatbow': 42,
#  'Great Runes': 41,
#  "Ordovis's Greatsword": 41,
#  "Alabaster Lord's Sword": 41,
#  'Scimitar': 41,
#  "Celebrant's Skull": 41,
#  'Butchering Knife': 41,
#  "Siluria's Tree": 41,
#  'Blue-White Wooden Shield': 41,
#  "Banished Knight's Shield": 41,
#  'Albinauric Shield': 41,
#  'Crystal Staff': 41,
#  'Erdtree Seal': 41,
#  'Erdtree Bow': 41,
#  'Black Bow': 41,
#  'Containers': 40,
#  'Erdsteel Dagger': 40,
#  'Blasphemous Blade': 40,
#  'Bloody Helice': 40,
#  'Falchion': 40,
#  'Wing of Astel': 40,
#  "Onyx Lord's Greatsword": 40,
#  'Hand of Malenia': 40,
#  'Greathorn Hammer': 40,
#  'Lance': 40,
#  'Lucerne': 40,
#  "Guardian's Swordspear": 40,
#  'Hookclaws': 40,
#  'Raptor Talons': 40,
#  "Prelate's Inferno Crozier": 40,
#  'Torch': 40,
#  'Dragon Towershield': 40,
#  'Jellyfish Shield': 40,
#  "Astrologer's Staff": 40,
#  'Inventory Menu': 39,
#  'Black Knife': 39,
#  'Inseparable Sword': 39,
#  'Regalia of Eochaid': 39,
#  'Dark Moon Greatsword': 39,
#  "Scavenger's Curved Sword": 39,
#  'Meteoric Ore Blade': 39,
#  'Dragonscale Blade': 39,
#  "Eleonora's Poleblade": 39,
#  'Great Mace': 39,
#  "Envoy's Long Horn": 39,
#  'Rusted Anchor': 39,
#  'Nightrider Glaive': 39,
#  'Golden Halberd': 39,
#  "Envoy's Greathorn": 39,
#  'Dragon Greatclaw': 39,
#  "Ghiza's Wheel": 39,
#  'Buckler': 39,
#  'Silver Mirrorshield': 39,
#  'Distinguished Greatshield': 39,
#  "Ant's Skull Plate": 39,
#  'Level Up Menu': 38,
#  'Glintstone Kris': 38,
#  'Lazuli Glintstone Sword': 38,
#  'Flamberge': 38,
#  'Godskin Stitcher': 38,
#  'Flowing Curved Sword': 38,
#  'Eclipse Shotel': 38,
#  'Zamor Curved Sword': 38,
#  "Envoy's Horn": 38,
#  'Jawbone Axe': 38,
#  "Rosus' Axe": 38,
#  'Death Ritual Spear': 38,
#  'Thorned Whip': 38,
#  'Urumi': 38,
#  'Riveted Wooden Shield': 38,
#  'Shield of the Guilty': 38,
#  'One-Eyed Shield': 38,
#  'Eclipse Crest Greatshield': 38,
#  'Frenzied Flame Seal': 38,
#  'Miséricorde': 37,
#  "Celebrant's Sickle": 37,
#  "Monk's Flameblade": 37,
#  'Twinblade': 37,
#  'Morning Star': 37,
#  'Spiked Club': 37,
#  'Treespear': 37,
#  'Clinging Bone': 37,
#  'Staff of the Avatar': 37,
#  'Red Thorn Roundshield': 37,
#  'Scripture Wooden Shield': 37,
#  'Beast Crest Heater Shield': 37,
#  'Black Leather Shield': 37,
#  'Cuckoo Greatshield': 37,
#  'Shortbow': 37,
#  'Jar Cannon': 37,
#  'Status Menu': 36,
#  'Short Sword': 36,
#  'Grossmesser': 36,
#  'Uchigatana': 36,
#  'Hammer': 36,
#  'Icerind Hatchet': 36,
#  'Pike': 36,
#  "Giant's Red Braid": 36,
#  'Twinbird Kite Shield': 36,
#  'Haligtree Crest Greatshield': 36,
#  'Carian Regal Scepter': 36,
#  'Finger Seal': 36,
#  "St. Trina's Arrow": 36,
#  'Golden Epitaph': 35,
#  'Nox Flowing Sword': 35,
#  'Iron Greatsword': 35,
#  "Serpent-God's Curved Sword": 35,
#  'Crescent Moon Axe': 35,
#  'Ice Crest Shield': 35,
#  'Briar Greatshield': 35,
#  'Staff of Loss': 35,
#  'Serpent Bow': 35,
#  'Lion Greatbow': 35,
#  'Golem Greatbow': 35,
#  'Arbalest': 35,
#  "Golem's Great Arrow": 35,
#  'Ornamental Straight Sword': 34,
#  'Estoc': 34,
#  'Shamshir': 34,
#  'Beastclaw Greathammer': 34,
#  'Nightrider Flail': 34,
#  "Watchdog's Staff": 34,
#  'Large Leather Shield': 34,
#  'Spiked Palisade Shield': 34,
#  "Digger's Staff": 34,
#  'Meteorite Staff': 34,
#  'Harp Bow': 34,
#  'Sword of Night and Flame': 33,
#  'Great Épée': 33,
#  'Pickaxe': 33,
#  'Ripple Blade': 33,
#  'Great Omenkiller Cleaver': 33,
#  "Executioner's Greataxe": 33,
#  "Loretta's War Sickle": 33,
#  'Whip': 33,
#  "Troll's Hammer": 33,
#  'Glintstone Staff': 33,
#  "Demi-Human Queen's Staff": 33,
#  "Crepus's Black-Key Crossbow": 33,
#  'Meteor Bolt': 33,
#  'Birdseye Telescopes': 32,
#  'Great Rune Menu': 32,
#  'Power of Remembrance Menu': 32,
#  "Warhawk's Talon": 32,
#  'Nagakiba': 32,
#  "Bastard's Stars": 32,
#  'Sacrificial Axe': 32,
#  'Beast-Repellent Torch': 32,
#  "Carian Knight's Shield": 32,
#  'Golden Beast Crest Shield': 32,
#  'Manor Towershield': 32,
#  "Azur's Glintstone Staff": 32,
#  'Hand Ballista': 32,
#  'Burred Bolt': 32,
#  'Parrying Dagger': 31,
#  'Cinquedea': 31,
#  "Watchdog's Greatsword": 31,
#  "Godslayer's Greatsword": 31,
#  'Mantis Blade': 31,
#  'Club': 31,
#  'Curved Great Club': 31,
#  'Family Heads': 31,
#  'Battle Axe': 31,
#  'Spear': 31,
#  'Cleanrot Spear': 31,
#  'Spiked Spear': 31,
#  'Glaive': 31,
#  'Caestus': 31,
#  'Venomous Fang': 31,
#  'Rickety Shield': 31,
#  'Sun Realm Shield': 31,
#  'Gilded Greatshield': 31,
#  'Gelmir Glintstone Staff': 31,
#  "Lusat's Glintstone Staff": 31,
#  'Clawmark Seal': 31,
#  'Greatbow': 31,
#  'Light Crossbow': 31,
#  'Spiritflame Arrow': 31,
#  "Radahn's Spear": 31,
#  'Dagger': 30,
#  'Crystal Knife': 30,
#  'Frozen Needle': 30,
#  "Vyke's War Spear": 30,
#  'Magma Whip Candlestick': 30,
#  'Steel-Wire Torch': 30,
#  'Gilded Iron Shield': 30,
#  'Round Shield': 30,
#  'Great Turtle Shell': 30,
#  'Eclipse Crest Heater Shield': 30,
#  'Crossed-Tree Towershield': 30,
#  'Golden Greatshield': 30,
#  "Lordsworn's Shield": 30,
#  "Giant's Seal": 30,
#  'Shattershard Arrow (Fletched)': 30,
#  'Shop Menu': 29,
#  "Dragon King's Cragblade": 29,
#  'Curved Club': 29,
#  "Celebrant's Cleaver": 29,
#  'Warped Axe': 29,
#  'Longhaft Axe': 29,
#  "Celebrant's Rib-Rake": 29,
#  'Rotten Crystal Spear': 29,
#  'Halo Scythe': 29,
#  'Smoldering Shield': 29,
#  'Inverted Hawk Towershield': 29,
#  'Golden Order Seal': 29,
#  'Longbow': 29,
#  'Horn Bow': 29,
#  'Rainbow Stone Arrow (Fletched)': 29,
#  'Golden Great Arrow': 29,
#  'Spirit Tuning Menu': 28,
#  "Beastman's Curved Sword": 28,
#  'Shotel': 28,
#  'Twinned Knight Swords': 28,
#  'Mace': 28,
#  'Warpick': 28,
#  "Monk's Flamemace": 28,
#  'Nox Flowing Hammer': 28,
#  'Hand Axe': 28,
#  "Clayman's Harpoon": 28,
#  "Heavy Cleanrot Knight's Spear": 28,
#  'Dragon Halberd': 28,
#  "Perfumer's Shield": 28,
#  'Coil Shield': 28,
#  'Candletree Wooden Shield': 28,
#  'Inverted Hawk Heater Shield': 28,
#  'Carian Glintstone Staff': 28,
#  'Buckshot Crossbow': 28,
#  'Golden Arrow': 28,
#  'Sleepbone Arrow (Fletched)': 28,
#  'Bloodbone Arrow (Fletched)': 28,
#  'Black-Key Bolt': 28,
#  'Bloodstained Dagger': 27,
#  'Magma Blade': 27,
#  "Heavy Varré's Bouquet": 27,
#  "Father Marika's Hammer": 27,
#  'Chainlink Flail': 27,
#  'Burial Axe': 27,
#  'Iron Ball': 27,
#  'Dragonclaw Shield': 27,
#  'Serpent Arrow': 27,
#  'Mixing Physicks': 26,
#  "Scorpion's Stinger": 26,
#  "Death's Poker": 26,
#  "Gargoyle's Blackblade": 26,
#  'Serpentbone Blade': 26,
#  'Abundance and Decay Twinblade': 26,
#  "Gargoyle's Black Blades": 26,
#  'Iron Cleaver': 26,
#  "Gargoyle's Black Axe": 26,
#  'Ripple Crescent Halberd': 26,
#  'Heavy Dragon Halberd': 26,
#  "Gargoyle's Black Halberd": 26,
#  'Duelist Greataxe': 26,
#  'Scorpion Kite Shield': 26,
#  'Heater Shield': 26,
#  'Crucible Hornshield': 26,
#  'Magicbone Arrow (Fletched)': 26,
#  'Haligbone Arrow (Fletched)': 26,
#  'Rotbone Arrow (Fletched)': 26,
#  'Item Crafting Menu': 25,
#  'Ivory Sickle': 25,
#  'Longsword': 25,
#  'Royal Soldier Straight Sword': 25,
#  "Noble's Slender Sword": 25,
#  "Cleanrot Knight's Sword": 25,
#  'Sharktooth Curved Sword': 25,
#  'Large Club': 25,
#  'Battle Hammer': 25,
#  'Short Spear': 25,
#  'Torchpole': 25,
#  'Spiked Caestus': 25,
#  'Iron Roundshield': 25,
#  'Albinauric Staff': 25,
#  'Firebone Arrow (Fletched)': 25,
#  'Poisonbone Arrow (Fletched)': 25,
#  'Bone Ballista Bolt': 25,
#  'Broadsword': 24,
#  "Noble's Estoc": 24,
#  "Morgott's Cursed Sword": 24,
#  'Abundance Twinblade': 24,
#  'Highland Axe': 24,
#  'Winged Scythe': 24,
#  'Fallingstar Beast Jaw': 24,
#  "St. Trina's Torch": 24,
#  "Man-Serpent's Shield": 24,
#  'Red Branch Shortbow': 24,
#  'Dwelling Arrow': 24,
#  "Gargoyle's Greatsword": 23,
#  "Gargoyle's Twinblade": 23,
#  "Gargoyle's Great Axe": 23,
#  "Gargoyle's Halberd": 23,
#  'Rotten Staff': 23,
#  'Kite Shield': 23,
#  'Blue-Gold Kite Shield': 23,
#  'Hawk Crest Wooden Shield': 23,
#  "Soldier's Crossbow": 23,
#  'Stormwing Bone Arrow': 23,
#  'Coldbone Arrow (Fletched)': 23,
#  'Bone Great Arrow': 23,
#  'Partisan': 22,
#  'Heavy Lava Whip': 22,
#  'Academy Glintstone Staff': 22,
#  "Godslayer's Seal": 22,
#  'Composite Bow': 22,
#  'Lightningbone Arrow (Fletched)': 22,
#  'Shattershard Arrow': 22,
#  'Great Arrow': 22,
#  "Perfumer's Bolt": 22,
#  'Flaming Bolt': 22,
#  'Imprisoned Merchant': 21,
#  'Great Knife': 21,
#  'Heavy Inseparable Sword': 21,
#  'Forked Greatsword': 21,
#  'Rotten Battle Hammer': 21,
#  'Horse Crest Wooden Shield': 21,
#  'Wooden Greatshield': 21,
#  'Carian Glintblade Staff': 21,
#  'Rainbow Stone Arrow': 21,
#  'Bone Great Arrow (Fletched)': 21,
#  'Bone Bolt': 21,
#  'Menu: Weapon Upgrades': 20,
#  'Rotten Crystal Sword': 20,
#  'Forked Hatchet': 20,
#  "Heretic's Hook": 20,
#  'Katar': 20,
#  'Brass Shield': 20,
#  'Redmane Greatshield': 20,
#  'Bone Arrow': 20,
#  'Sleepbone Arrow': 20,
#  'Bloodbone Arrow': 20,
#  "Golem's Magic Arrow": 20,
#  "Lordsworn's Bolt": 20,
#  'Bloodbone Bolt': 20,
#  'Menu: Additional Healing Flasks': 19,
#  'Menu: Increasing Healing Amount': 19,
#  'Heavy Sword of Milos': 19,
#  "Bloodhound's Fang": 19,
#  'Moonveil': 19,
#  "Golem's Halberd": 19,
#  'Rotten Greataxe': 19,
#  'Rift Shield': 19,
#  'Rotten Crystal Staff': 19,
#  'Lightning Bolt': 19,
#  'Golden Bolt': 19,
#  'Sleepbone Bolt': 19,
#  'Holy Inferno Greatsword': 18,
#  'Bloodhound Claws': 18,
#  "Heavy Watchdog's Crosier": 18,
#  'Blue Crest Heater Shield': 18,
#  'Misbegotten Shortbow': 18,
#  'Magicbone Arrow': 18,
#  'Haligbone Arrow': 18,
#  'Rotbone Arrow': 18,
#  'Magicbone Bolt': 18,
#  'Haligbone Bolt': 18,
#  'Rotbone Bolt': 18,
#  'Explosive Greatbolt': 18,
#  'Albinauric Bow': 17,
#  'Bone Arrow (Fletched)': 17,
#  'Firebone Arrow': 17,
#  'Poisonbone Arrow': 17,
#  'Firebone Bolt': 17,
#  'Poisonbone Bolt': 17,
#  'Menu: Dragon Communion Shop': 16,
#  'Star Fist': 16,
#  'Red Crest Heater Shield': 16,
#  "Occult Marika's Hammer": 15,
#  'Coldbone Arrow': 15,
#  'Coldbone Bolt': 15,
#  'Arrow': 14,
#  'Lightningbone Arrow': 14,
#  'Storm Arrow': 14,
#  'Explosive Bolt': 14,
#  'Lightningbone Bolt': 14,
#  'Iron Spear': 13,
#  'Heavy Crossbow': 13,
#  'Lightning Greatbolt': 13,
#  'Heavy Erdtree Greatshield': 12,
#  'Ballista Bolt': 11,
#  'Unarmed': 10,
#  'Bolt': 10,
#  'Fire Arrow': 9,
#  "Heavy Gargoyle's Blackblade": 8,
#  "Heavy Gargoyle's Black Axe": 8,
#  "Heavy Gargoyle's Black Halberd": 8,
#  'The Noble Goldmask': 7,
#  'Using Items': 2}

# %%
CUTOFF = 99
valid_speakers = L(spkr for spkr, count in speaker_counts_sorted.items() if count >= 100); valid_speakers
# Out:
# (#47) ['Sir Gideon Ofnir, the All-Knowing','Alexander, Warrior Jar','Sorcerer Rogier','Preceptor Seluvis','Rya the Scout','White Mask Varré','Roderika, Spirit Tuner','Scribe Corhyn','Jar-Bairn','Merchant Kalé'...]

# %%
valid_entries = L(entry for entry in entries if entry['speaker'] in valid_speakers); valid_entries
# Out:
# (#1296) [{'words': 'Have you heard of the Finger Maidens? They serve the Two Fingers, offering guidance, and aid, to the Tarnished. But you, I am afraid, are maidenless. I can play the role of maiden. Turning runes into strength. To aid you in your search for the Elden Ring. You need only take me with you. To the foot of the Erdtree.', 'speaker': 'Melina', 'turn': 'Section 10'},{'words': "Then it's settled. Summon me by grace to turn runes into strength. Ahh, another matter. I bequeath to you this ring. Use it to traverse great distances. It will summon a spectral steed named Torrent. Torrent has chosen you. Treat him with respect.", 'speaker': 'Melina', 'turn': 'Section 11'},{'words': "I understand. I'm asking you to put faith in but a stranger. Yet I'm certain that we can reach an understanding. Summon me by grace if you should reconsider.", 'speaker': 'Melina', 'turn': 'Section 12'},{'words': 'Have you reconsidered my offer?', 'speaker': 'Melina', 'turn': 'Section 13'},{'words': 'Shall I turn your runes to strength? Let my hand rest upon you, for but a moment.', 'speaker': 'Melina', 'turn': 'Section 20'},{'words': 'Phew. It is done.', 'speaker': 'Melina', 'turn': 'Section 22'},{'words': "This tiny golden aura is the grace of the Erdtree. This light once shone in the eyes of your Tarnished brethren. But now it is all that guides you. Or so I hear. You can see them, can't you? The rays of grace, that guide you through your burden.", 'speaker': 'Melina', 'turn': 'Section 30'},{'words': "Me? I'm searching. For my purpose, given to me by my mother inside the Erdtree, long ago. For the reason that I yet live, burned and bodiless. There is something for which I must apologise. I've acted the Finger Maiden, yet can offer no guidance. I am no maiden. My purpose…was long ago lost.", 'speaker': 'Melina', 'turn': 'Section 31'},{'words': 'Upon the cliff, in Castle Stormveil, is a shardbearer. A demigod who inherited a fragment of the shattered Elden Ring. If the rays of grace signal the castle, then the Elden Ring beckons you. As an ally by pact, ...I pray that you are fit... To face the challenge presented by the Ring.', 'speaker': 'Melina', 'turn': 'Section 32'},{'words': 'Spoken echoes linger here. Words of Queen Marika, who vanished long ago. If you wish, I will share them with you.', 'speaker': 'Melina', 'turn': 'Section 40'}...]

# %%
plt.plot([speaker_counts_sorted[spkr] for spkr in valid_speakers])

# %%
valid_data = {spkr: vals for spkr, vals in by_speaker.items() if spkr in valid_speakers}

# %%
top_spkrs = L(valid_speakers[:3])
name = top_spkrs[0]

# %%
print(
    '\n'.join(
        o['words'] 
        for o in valid_data[valid_speakers[2]]
    )
)
# Out:
# Ah, nice to meet you. The pleasure's mine. Rogier's the name. A sorcerer, as you might have guessed. I'm looking for a little something, here in the castle. When I'm not hotfooting it from the troops, that is. But enough about me, what are you doing here in Stormveil Castle? This place is bristling with Tarnished hunters, you know. They sacrifice our kind, for grafting. Not exactly a place I'd stroll into without a purpose in mind...
#   'speaker': 'War Counselor Iji',
#   'turn': 'Section 50'},
#  {'words': "Unthinkable, how could Blaidd... How did he break free from his cell? No, more importantly... Blaidd became a curse that plagued Lady Ranni, yet even in madness, gave himself to her. I've made a grave misjudgment. And I thought myself a capable war counsellor... I'll catch up with you soon enough, Blaidd. When I do, I only hope you'll accept my apology.",
#   'speaker': 'War Counselor Iji',
#   'turn': 'Section 70'},
#  {'words': "Oh, pardon me. It's hardly my place to ask, is it. I am Iji. A blacksmith who once served the Carian royals… An old codger who refuses to retire his rusty hammer. So, here I am, still quietly plying my trade, on this spot. Perhaps you'd like a display? These bones are old, but still able.",
#   'speaker': 'War Counselor Iji',
#   'turn': 'Section 10'},
#  {'words': 'My apologies for the misleading words of warning. I never imagined that an audience, let alone service to Lady Ranni was in your fate. I, for one, should have seen it, but I did not. Do forgive me, my fellow. Let us give all that we can of ourselves. Together, for Lady Ranni.',
#   'speaker': 'War Counselor Iji',
#   'turn': 'Section 33'},
#  {'words': "Oh, watch out, there. When I'm absorbed in my smithing, I lose sight of all else. If you come too close, I'm apt to cause you harm. I am, after all, terribly large compared to you, Tarnished. You don't know how hard it is not to break anything while I work.",
#   'speaker': 'War Counselor Iji',
#   'turn': 'Section 14'},
#  {'words': "Oh, so you were the one. Lady Ranni has explained everything. Again, I am Iji. The Carian royal family's dedicated blacksmith, and Lady Ranni's war counsellor. I am told that you are searching for Nokron with Blaidd. I will give you whatever guidance I can. And pray, for your success.",
#   'speaker': 'War Counselor Iji',
#   'turn': 'Section 20'},
#  {'words': "Blaidd actually did that, did he? Quite a rare occurrence, for such a guarded soul as he. Perhaps he sensed something unusual about you. At any rate, if you're friendly with Blaidd, I've a few more things that might suit you. I've something else that might suit you.",
#   'speaker': 'War Counselor Iji',
#   'turn': 'Section 17'},
#  {'words': "The Carian royal family's dedicated blacksmith, and Lady Ranni's war counsellor. I am told that you are searching for Nokron with Blaidd. I will give you whatever guidance I can. And pray, for your success.",
#   'speaker': 'War Counselor Iji',
#   'turn': 'Section 23'},
#  {'words': 'You need not await Blaidd. Descend underground alone where the fallen star struck Limgrave. And make it yours. The precious treasure of Nokron. So that Lady Ranni may tread the dark path of the Empyrean.',
#   'speaker': 'War Counselor Iji',
#   'turn': 'Section 42'},
#  {'words': 'Oh, Blaidd wanted me to tell you. Not to bother waiting for him, and head straight to Nokron. Blaidd has been given an important task. Apparently, a matter of great urgency.',
#   'speaker': 'War Counselor Iji',
#   'turn': 'Section 41'},
#  {'words': 'Go with Blaidd to the festival grounds. Should General Radahn be defeated, the stars would once again resume their movement. Perhaps revealing the elusive path to Nokron.',
#   'speaker': 'War Counselor Iji',
#   'turn': 'Section 39'},
#  {'words': "I've explained the peril. Of the enchanted snare that remains at the royal Carian Manor. Whatever you do, brave Tarnished, stay away from that deathtrap.",
#   'speaker': 'War Counselor Iji',
#   'turn': 'Section 16'},
#  {'words': "Well, it's kind of you to speak to me again. Then I presume these old bones served their purpose, more or less?",
#   'speaker': 'War Counselor Iji',
#   'turn': 'Section 11'},
#  {'words': "Well, look at you. We don't receive many visitors. I presume you are a Tarnished. What brings you here?",
#   'speaker': 'War Counselor Iji',
#   'turn': 'Section 01'},
#  {'words': 'Oh, then you must be the one. Lady Ranni has explained everything. The pleasure is mine. I am Iji.',
#   'speaker': 'War Counselor Iji',
#   'turn': 'Section 24'},
#  {'words': 'Well, my fellow. How may I serve you? As war counsellor, or as blacksmith?',
#   'speaker': 'War Counselor Iji',
#   'turn': 'Section 36'},
#  {'words': 'Let us give all that we can of ourselves. Together, for Lady Ranni.',
#   'speaker': 'War Counselor Iji',
#   'turn': 'Section 34'},
#  {'words': 'Let us give all that we can of ourselves. Together, for Lady Ranni.',
#   'speaker': 'War Counselor Iji',
#   'turn': 'Section 35'},
#  {'words': 'Brave Tarnished. Here to put my old bones to work again?',
#   'speaker': 'War Counselor Iji',
#   'turn': 'Section 12'},
#  {'words': 'Greetings, my fellow. How can I help?',
#   'speaker': 'War Counselor Iji',
#   'turn': 'Section 37'},
#  {'words': 'Something else for you?',
#   'speaker': 'War Counselor Iji',
#   'turn': 'Section 15'},
#  {'words': 'Something else for you?',
#   'speaker': 'War Counselor Iji',
#   'turn': 'Section 38'}]
